# %% [markdown]
# ### importing packages

# %%
## importing relevant packages

## interact with the operating system (file paths, directories, environment variables)
import os
## not needed right now
## bringing in Google Drive so files can be accessed inside Google Colab
#from google.colab import drive
#from google.colab import sheets
# using this for my database
import duckdb

# so i can easily display images
from IPython.display import Image, display

## numerical computing library used for fast array operations and math
import numpy as np
## built on numpy, helps with modeling data: data manipulation and analysis (DataFrames, grouping, filtering)
import pandas as pd
## formats tables nicely when printing to the console
from prettytable import PrettyTable

## type hints for functions (for debugging)
from typing import List
## built-in datetime tools for creating and manipulating dates/times
from datetime import datetime

## (simple plotting) core plotting library used to create charts (line, bar, scatter etc)
import matplotlib.pyplot as plt
## tools for formatting dates on chart axes
from matplotlib.dates import date2num, DateFormatter, MonthLocator
# both needed for driver analysis stats
from scipy.stats import t, ttest_ind_from_stats
from math import sqrt

## (complex potting) high-level statistical visualization library built on matplotlib (e.g. heatmaps, boxplots)
import seaborn as sns

## for statistical analysis (e.g. OLS / regression etc)
import statsmodels.api as sm
## used to create models from a formula + dataframe
import statsmodels.formula.api as smf

## bringing in plotly
## low-level interface for building fully customized plotly charts (e.g. go.scatter())
import plotly.graph_objects as go
## can make plots quicker (basically in one line)
import plotly.express as px
## allows creating subplots and putting them in a grid of some description
from plotly.subplots import make_subplots
import textwrap

print('import done')
# Out:
# import done

# %%
# for writing sql
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# #### connecting to my database and listing the tables in it

# %%
conn = duckdb.connect('../data/aotearoa-data-project_view.duckdb')

conn.sql("SHOW TABLES").df()
# Out:
#                   name
# 0         dim_calendar
# 1   my_first_dbt_model
# 2  my_second_dbt_model
# 3         stg_calendar

# %% [markdown]
# #### creating dataframe from table

# %%
grabbing_data_df = pd.read_sql_query('SELECT * FROM dim_calendar', conn)

print(grabbing_data_df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21900 entries, 0 to 21899
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   date_day                        21900 non-null  object
#  1   prior_date_day                  21900 non-null  object
#  2   next_date_day                   21900 non-null  object
#  3   prior_year_date_day             21900 non-null  object
#  4   prior_year_over_year_date_day   21900 non-null  object
#  5   day_of_week                     21900 non-null  int64
#  6   day_of_week_iso                 21900 non-null  int64
#  7   day_of_week_name                21900 non-null  str
#  8   day_of_week_name_short          21900 non-null  str
#  9   day_of_week_name_te_reo_arotau  21900 non-null  str
#  10  day_of_week_name_te_reo         21900 non-null  str
#  11  day_of_month                    21900 non-null  int64
#  12  day_of_year                     21900 non-null  int64
#  13  week_start_date                 21900 non-null  object
#  14  week_end_date                   21900 non-null  object
#  15  prior_year_week_start_date      21900 non-null  object
#  16  prior_year_week_end_date        21900 non-null  object
#  17  week_of_year                    21900 non-null  int64
#  18  iso_week_start_date             21900 non-null  object
#  19  iso_week_end_date               21900 non-null  object
#  20  prior_year_iso_week_start_date  21900 non-null  object
#  21  prior_year_iso_week_end_date    21900 non-null  object
#  22  iso_week_of_year                21900 non-null  int64
#  23  iso_year_week                   21900 non-null  str
#  24  prior_year_week_of_year         21900 non-null  int64
#  25  prior_year_iso_week_of_year     21900 non-null  int64
#  26  month_of_year                   21900 non-null  int64
#  27  month_name                      21900 non-null  str
#  28  month_name_short                21900 non-null  str
#  29  month_name_te_reo_arotau        21900 non-null  str
#  30  month_name_te_reo               21900 non-null  str
#  31  month_start_date                21900 non-null  object
#  32  month_end_date                  21900 non-null  object
#  33  prior_year_month_start_date     21900 non-null  object
#  34  prior_year_month_end_date       21900 non-null  object
#  35  quarter_of_year                 21900 non-null  int64
#  36  quarter_start_date              21900 non-null  object
#  37  quarter_end_date                21900 non-null  object
#  38  year_number                     21900 non-null  int64
#  39  year_start_date                 21900 non-null  object
#  40  year_end_date                   21900 non-null  object
# dtypes: int64(11), object(21), str(9)
# memory usage: 6.9+ MB
# None
# /var/folders/ts/3r4y298n331d867g1fzbw1y80000gn/T/ipykernel_64678/1749264757.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   grabbing_data_df = pd.read_sql_query('SELECT * FROM dim_calendar', conn)
